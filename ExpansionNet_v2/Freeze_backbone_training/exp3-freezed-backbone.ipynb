# %%
import gdown
# !gdown --id 1BhzcTOWU-bCagjhzR1bWv0ADwKHN135T
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1BhzcTOWU-bCagjhzR1bWv0ADwKHN135T
# From (redirected): https://drive.google.com/uc?id=1BhzcTOWU-bCagjhzR1bWv0ADwKHN135T&confirm=t&uuid=95fc5ace-cbf1-44c1-9df7-d845d61838ba
# To: /kaggle/working/ExpansionNet_v2.zip
# 100%|██████████████████████████████████████| 4.70G/4.70G [01:00<00:00, 77.3MB/s]

# %%
#https://drive.google.com/file/d/1BhzcTOWU-bCagjhzR1bWv0ADwKHN135T/view?usp=sharing

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !unzip -q ExpansionNet_v2.zip

# %%
# %cd /kaggle/working/ExpansionNet_v2
# Out:
# /kaggle/working/ExpansionNet_v2

# %%
# !sed -i 's/\r//' ./eval/get_stanford_models.sh

# %%
# !chmod +x ./eval/get_stanford_models.sh

# %%
# !python train.py --N_enc 3 --N_dec 3 \
    --model_dim 512 --seed 775533 --optim_type radam --sched_type custom_warmup_anneal \
    --warmup 100 --lr 2e-4 --anneal_coeff 0.8 --anneal_every_epoch 2 --enc_drop 0.3 \
    --dec_drop 0.3 --enc_input_drop 0.3 --dec_input_drop 0.3 --drop_other 0.3 \
    --batch_size 48 --num_accum 1 --num_gpus 2 --ddp_sync_port 12325 --eval_beam_sizes [3] \
    --save_path ./github_ignore_material/saves/ --save_every_minutes 60 --how_many_checkpoints 1 \
    --is_end_to_end False --features_path ./github_ignore_material/raw_data/features.hdf5 --partial_load False \
    --print_every_iter 100 --eval_every_iter 100 \
    --images_path ./ktvic_dataset/ \
    --reinforce False --num_epochs 8 > output_file.txt 2>&1
